# %% [markdown]
# <a href="https://colab.research.google.com/github/nikunjmahajan5/ExploratroryDataAnalysis_Telecom/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-809cfe01-34dc-437b-8cde-64b1173ddb7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-809cfe01-34dc-437b-8cde-64b1173ddb7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Telecom Churn (3).csv to Telecom Churn (3) (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Telecom Churn (3).csv']))

# %%
df2.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#getting information about data
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
print(df2[['State','Account length']])
# Out:
#      State  Account length
# 0       KS             128
# 1       OH             107
# 2       NJ             137
# 3       OH              84
# 4       OK              75
# ...    ...             ...
# 3328    AZ             192
# 3329    WV              68
# 3330    RI              28
# 3331    CT             184
# 3332    TN              74
#
# [3333 rows x 2 columns]

# %%
df2.loc[df2['State']=='KS']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 179     KS              70        408                 No              No
# 258     KS              92        408                Yes              No
# 287     KS             137        408                 No              No
# 368     KS             132        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3217    KS             164        510                 No             Yes
# 3244    KS             101        415                 No              No
# 3253    KS             127        415                 No             Yes
# 3285    KS              57        415                 No              No
# 3287    KS             170        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
